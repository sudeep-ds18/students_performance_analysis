# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# . Data Checks to perform
#
# Check Missing values
# Check Duplicates
# Check data type
# Check the number of unique values of each column
# Check statistics of data set
# Check various categories present in the different categorical column

# %%
df = pd.read_csv("stud.csv")

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
#  8   total_score                  1000 non-null   int64
#  9   average_score                1000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 78.2+ KB

# %%
df["total_score"] = df["math_score"] + df["reading_score"] + df["writing_score"]

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
df["average_score"] = (df["math_score"] + df["reading_score"] + df["writing_score"])/3

# %% [markdown]
# df.shape

# %%
# Checking Missing values

# %%
df.isna().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# total_score                    0
# average_score                  0
# dtype: int64

# %%
df.duplicated().sum()  #checking duplicate values
# Out:
# 0

# %% [markdown]
# 0 duplicate values And 0 missing values
# Total 10 columns 5 of object and 5 of numerical

# %%
# gives number of unique values 
df.nunique()
# Out:
# gender                           2
# race_ethnicity                   5
# parental_level_of_education      6
# lunch                            2
# test_preparation_course          2
# math_score                      81
# reading_score                   72
# writing_score                   77
# total_score                    194
# average_score                  194
# dtype: int64

# %% [markdown]
# gender = 2 -- male female
# race_ethinicity -- 5  A< B< C< D< E
# test_preparation_course --- leads to good marks above 75 aprrox

# %%
df.head(20)
# Out:
#     gender race_ethnicity parental_level_of_education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score  total_score  average_score
# count  1000.00000    1000.000000    1000.000000  1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000   203.312000      67.770667
# std      15.16308      14.600192      15.195657    42.771978      14.257326
# min       0.00000      17.000000      10.000000    27.000000       9.000000
# 25%      57.00000      59.000000      57.750000   175.000000      58.333333
# 50%      66.00000      70.000000      69.000000   205.000000      68.333333
# 75%      77.00000      79.000000      79.000000   233.000000      77.666667
# max     100.00000     100.000000     100.000000   300.000000     100.000000

# %%
print("categories present in the categorical column " , end = " ")
print(df["gender"].unique())

print("categories present in the categorical column ",end= " ")
print(df["race_ethnicity"].unique())

print("categories present in the categorical column ",end= " ")
print(df['parental_level_of_education'].unique())

print("categories present in the categorical column ",end= " ")
print(df["lunch"].unique())

print("categories present in the categorical column ",end= " ")
print(df["test_preparation_course"].unique())
# Out:
# categories present in the categorical column  ['female' 'male']
# categories present in the categorical column  ['group B' 'group C' 'group A' 'group D' 'group E']
# categories present in the categorical column  ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# categories present in the categorical column  ['standard' 'free/reduced']
# categories present in the categorical column  ['none' 'completed']

# %%
full_marks_math = df[df["math_score"]==100].shape[0]

# %%
full_marks_math
# Out:
# 7

# %%
full_marks_reading = df[df["reading_score"]==100].shape[0]

# %%
full_marks_reading
# Out:
# 17

# %%
full_marks_writing = df[df["writing_score"]==100].shape[0]

# %%
full_marks_writing
# Out:
# 14

# %%
full_marks_all = df[(df["math_score"]==100) &
                    (df["reading_score"]==100) &
                    (df["writing_score"]==100)
]

# %%
full_marks_all
# Out:
#      gender race_ethnicity parental_level_of_education     lunch  \
# 458  female        group E           bachelor's degree  standard
# 916    male        group E           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
#
#      total_score  average_score
# 458          300          100.0
# 916          300          100.0
# 962          300          100.0

# %%
#Students who fails
fail_math = df[df["math_score"]<=35].shape[0]

# %%
fail_math
# Out:
# 27

# %%
fail_reading= df[df["reading_score"]<=35].shape[0]
fail_reading
# Out:
# 15

# %%
fail_writing = df[df["writing_score"]<=35].shape[0]
fail_writing
# Out:
# 18

# %%
# Total fail students
total_fail = df[
(df["math_score"]<=35)&
(df["reading_score"]<=35)&
(df["writing_score"]<=35)
]

# %%
total_fail
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 17   female        group B            some high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 76     male        group E            some high school      standard
# 211    male        group C                some college  free/reduced
# 327    male        group A                some college  free/reduced
# 363  female        group D            some high school  free/reduced
# 596    male        group B                 high school  free/reduced
# 601  female        group C                 high school      standard
# 980  female        group B                 high school  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# 17                     none          18             32             28
# 59                     none           0             17             10
# ...
